# %%
2+2
# Out:
# 4

# %%
a = 9
b = 10

a*b
# Out:
# 90

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.zeros([100, 100])

# %%
plt.imshow(A)
plt.show()

# %%
A.shape
# Out:
# (100, 100)

# %%
x_center = int(A.shape[0]/2)
y_center = int(A.shape[1]/2)

# %%
R = 25

# %%
import math

# %%
for x in range (0, A.shape[0]):
    for y in range (0, A.shape[1]):    
        if math.sqrt((x-x_center)**2+(y-y_center)**2)<R:
            A[x,y] = 1

# %%
plt.imshow(A, vmin=0, vmax=1)
plt.show()

# %%
import imageio

# %%
img_3ch = imageio.imread(r"C:\Users\e.lavrova\Documents\Python Scripts\blood.jpg")

# %%
img_3ch.shape
# Out:
# (3705, 5600, 3)

# %%
plt.imshow(img_3ch)
plt.show()

# %%
plt.figure(figsize=(10, 10))

plt.subplot(131)
plt.imshow(img_3ch[..., 0])

plt.subplot(132)
plt.imshow(img_3ch[..., 1])

plt.subplot(133)
plt.imshow(img_3ch[..., 2])

plt.show()

# %%
img_bw = np.mean(img_3ch, axis = 2)

# %%
plt.imshow(img_bw)
plt.show()

# %%
plt.hist(img_bw.flatten(), bins = 100)
plt.show()

# %%
th = 225

mask = img_bw<th

# %%
plt.imshow(mask)
plt.show()

# %%
plt.imshow(img_bw)
plt.contour(mask, colors = 'r')
plt.show()
