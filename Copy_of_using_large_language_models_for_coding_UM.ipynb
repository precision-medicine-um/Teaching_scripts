# %% [markdown]
# # Simple coding using generative AI
# Maastricht University Teaching script
#
# *Henry Woodruff*
#
#
# This notebook demonstrates how to use generative AI embedded in google colab to write simple code.
#
# In the following we will describe the steps in plain text and use this text as a prompt for the 'generate code' feature of colab.
#
# Here is a screenshot of a new blank code cell:
#
# ![code_cell.png](data:image/png;base64,...)
#
# Click on the _generate_ link and enter the prompt.
#
# ![generate.png](data:image/png;base64,...)
#
# Let's first try with the first step with a real code cell below. Something simple like 2+2.

# %% [markdown]
# Now something more advanced. Most applications will require you to install packages that contain useful pre-defined functions. Enter this prompt (in this notebook we print them bold):
#
# **install numpy and matplotlib.pyplot**
#
# Press enter and the code will appear in the cell below.
#
# To execute the code, please press the "run" button on the left side of the code cell.
#
# This will install the required packages on the colab virtual machine.

# %%
# prompt: Create and display and Empty image of dimensions 100x100

# !pip install numpy matplotlib

import numpy as np
import matplotlib.pyplot as plt

# Create an empty image (all pixels are black)
empty_image = np.zeros((100, 100, 3), dtype=np.uint8)

# Display the image
plt.imshow(empty_image)
plt.show()

# %% [markdown]
# Next, we create a "canvas" to paint on
#
# **Create and display and Empty image of dimensions 100x100**

# %% [markdown]
# Now let's see if we can draw a circle of diameter 50px
#
# **can you please draw a circle of diameter 50 in “image” and display it?**

# %% [markdown]
# The next step is to download an image. Again we will use the code cell below to do this. For the prompt we only need the URL of the image. For this exercise, we will use publicly available data.
#
# **Download and save the image from https://cdn.britannica.com/45/12045-004-01098020/Human-red-blood-cells.jpg**

# %% [markdown]
# Next, lets read the image and get some info about it
#
# **Please load the image and give me some info about it**

# %% [markdown]
# You can see that this image is in RGB format, so we need to read it in three channels.
#
# **Display the 3 channels separately**

# %% [markdown]
# Now let's do something a bit more advanced. Let's flatten the image (reduce to one channel) and display a histogram.
#
# **can you please flatten the image and display the histogram?**

# %% [markdown]
# Interesting! There is a dip at higher intensities.
#
# **where is the minimum in the histogram between pixel intensities 200 and 225?**

# %% [markdown]
# OK, one last step to see how powerful this new paradigm can be
#
# **can you please produce a binary mask based on the intensity threshold 205 and then display the original image overlaid by the contours of this mask**
